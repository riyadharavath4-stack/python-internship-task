# %%
#Problem 1: Smart Light Controller
class SmartLight:
  def __init__(self, name):
    self.name = name
    self.status = "OFF"
  def turn_on(self):
    self.status="ON"
  def turn_off(self):
    self.status = "OFF"
  def display_status(self):
    print(self.name + "is" + self.status)
light_name = input("Light Name:")
action = input("Action:")
light = SmartLight(light_name)
if action =="ON":
  light.turn_on()
elif action == "OFF":
  light.turn_off()
light.display_status()
# Out:
# Light Name:Bedroom Light
# Action:ON
# Bedroom LightisON

# %%
#Problem 2: Employee ID Card System
class Employee:
  def __init__(self,name,emp_id,department):
    self.name = name
    self.emp_id = emp_id
    self.department = department
  def display_id_card(self):
    print("Employee ID Card")
    print("Name:",self.name)
    print("ID:",self.emp_id)
    print("Department:",self.department)
name = input("Enter Employee Name: ")
emp_id = input("Enter Employee ID: ")
department = input("Enter Department: ")
emp = Employee(name,emp_id,department)
print()
emp.display_id_card()
# Out:
# Enter Employee Name: padhu
# Enter Employee ID: 0126
# Enter Department: IT
#
# Employee ID Card
# Name: padhu
# ID: 0126
# Department: IT

# %%
#Problem 3: Mobile Contact Record
class Contact:
  def __init__(self,name,phone):
    self.name = name
    self.phone = phone
  def display(self):
    print("Contact Saved")
    print("Name:",self.name)
    print("Phone:",self.phone)
name = input("Enter Contact Name: ")
phone = input("Enter Phone Number: ")
c = Contact(name,phone)
c.display()
# Out:
# Enter Contact Name: Anita
# Enter Phone Number: 801956728
# Contact Saved
# Name: Anita
# Phone: 801956728

# %%
#Problem 4: Product Price Tag Generator
class Product:
  def __init__(self,name,price):
    self.name = name
    self.price = price
  def display(self):
    print("Product:", self.name)
    print("Price: ₹" + str(self.price))
name = input("Enter Product Name: ")
price = int(input("Enter Price: "))
p = Product(name,price)
p.display()
# Out:
# Enter Product Name: Headphones
# Enter Price: 2499
# Product: Headphones
# Price: ₹2499

# %%
#Problem 5: Movie Rating Display System
class Movie:
  def __init__(self,name,rating):
    self.name = name
    self.rating = rating
  def display(self):
    print("Movie:",self.name)
    print("Rating:",self.rating,"/5")
name = input("Enter Movie Name: ")
rating = float(input("Enter Rating: "))
m = Movie(name,rating)
m.display()
# Out:
# Enter Movie Name: sirai
# Enter Rating: 5
# Movie: sirai
# Rating: 5.0 /5

# %%
#Problem 6: Delivery Address Manager
class Delivery:
  def __init__(self,name,address):
    self.name = name
    self.address = address
  def display(self):
    print("Customers Name:",self.name)
    print("Address:",self.address)
name = input("Enter Customer Name: ")
address = input("Enter Address: ")
d = Delivery(name,address)
d.display()
# Out:
# Enter Customer Name: padhu
# Enter Address: hyd
# Customers Name: padhu
# Address: hyd
